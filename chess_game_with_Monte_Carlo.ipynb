# %%
import chess
import chess.pgn
import chess.engine
import random
import time
from math import log,sqrt,e,inf

class node():
    def __init__(self):
        self.state = chess.Board()
        self.action = ''
        self.children = set()
        self.parent = None
        self.N = 0
        self.n = 0
        self.v = 0

def ucb1(curr_node):
    ans = curr_node.v+2*(sqrt(log(curr_node.N+e+(10**-6))/(curr_node.n+(10**-10))))
    return ans

def rollout(curr_node):
    
    if(curr_node.state.is_game_over()):
        board = curr_node.state
        if(board.result()=='1-0'):
            #print("h1")
            return (1,curr_node)
        elif(board.result()=='0-1'):
            #print("h2")
            return (-1,curr_node)
        else:
            return (0.5,curr_node)
    
    all_moves = [curr_node.state.san(i) for i in list(curr_node.state.legal_moves)]
    
    for i in all_moves:
        tmp_state = chess.Board(curr_node.state.fen())
        tmp_state.push_san(i)
        child = node()
        child.state = tmp_state
        child.parent = curr_node
        curr_node.children.add(child)
    rnd_state = random.choice(list(curr_node.children))

    return rollout(rnd_state)

def expand(curr_node,white):
    if(len(curr_node.children)==0):
        return curr_node
    max_ucb = -inf
    if(white):
        idx = -1
        max_ucb = -inf
        sel_child = None
        for i in curr_node.children:
            tmp = ucb1(i)
            if(tmp>max_ucb):
                idx = i
                max_ucb = tmp
                sel_child = i

        return(expand(sel_child,0))

    else:
        idx = -1
        min_ucb = inf
        sel_child = None
        for i in curr_node.children:
            tmp = ucb1(i)
            if(tmp<min_ucb):
                idx = i
                min_ucb = tmp
                sel_child = i

        return expand(sel_child,1)

def rollback(curr_node,reward):
    curr_node.n+=1
    curr_node.v+=reward
    while(curr_node.parent!=None):
        curr_node.N+=1
        curr_node = curr_node.parent
    return curr_node

def mcts_pred(curr_node,over,white,iterations=10):
    if(over):
        return -1
    all_moves = [curr_node.state.san(i) for i in list(curr_node.state.legal_moves)]
    map_state_move = dict()
    
    for i in all_moves:
        tmp_state = chess.Board(curr_node.state.fen())
        tmp_state.push_san(i)
        child = node()
        child.state = tmp_state
        child.parent = curr_node
        curr_node.children.add(child)
        map_state_move[child] = i
        
    while(iterations>0):
        if(white):
            idx = -1
            max_ucb = -inf
            sel_child = None
            for i in curr_node.children:
                tmp = ucb1(i)
                if(tmp>max_ucb):
                    idx = i
                    max_ucb = tmp
                    sel_child = i
            ex_child = expand(sel_child,0)
            reward,state = rollout(ex_child)
            curr_node = rollback(state,reward)
            iterations-=1
        else:
            idx = -1
            min_ucb = inf
            sel_child = None
            for i in curr_node.children:
                tmp = ucb1(i)
                if(tmp<min_ucb):
                    idx = i
                    min_ucb = tmp
                    sel_child = i

            ex_child = expand(sel_child,1)

            reward,state = rollout(ex_child)

            curr_node = rollback(state,reward)
            iterations-=1
    if(white):
        
        mx = -inf
        idx = -1
        selected_move = ''
        for i in (curr_node.children):
            tmp = ucb1(i)
            if(tmp>mx):
                mx = tmp
                selected_move = map_state_move[i]
        return selected_move
    else:
        mn = inf
        idx = -1
        selected_move = ''
        for i in (curr_node.children):
            tmp = ucb1(i)
            if(tmp<mn):
                mn = tmp
                selected_move = map_state_move[i]
        return selected_move

board = chess.Board()

white = 1
moves = 0
pgn = []
game = chess.pgn.Game()
evaluations = []
sm = 0
cnt = 0
while((not board.is_game_over())):
    all_moves = [board.san(i) for i in list(board.legal_moves)]
    #start = time.time()
    root = node()
    root.state = board
    result = mcts_pred(root,board.is_game_over(),white)
    #sm+=(time.time()-start)
    board.push_san(result)
    #print(result)
    pgn.append(result)
    white ^= 1
    #cnt+=1
    
    moves+=1
    print(board)

print(board)
print(" ".join(pgn))
print()
#print(evaluations)
print(board.result())
game.headers["Result"] = board.result()
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# N . . . . . . .
# P P P P P P P P
# R . B Q K B N R
# r n b q k b n r
# p p p p p p . p
# . . . . . . p .
# . . . . . . . .
# . . . . . . . .
# N . . . . . . .
# P P P P P P P P
# R . B Q K B N R
# r n b q k b n r
# p p p p p p . p
# . . . . . . p .
# . . . . . . . .
# . . . . . . . .
# N . . . . . P .
# P P P P P P . P
# R . B Q K B N R
# r n b q k . n r
# p p p p p p b p
# . . . . . . p .
# . . . . . . . .
# . . . . . . . .
# N . . . . . P .
# P P P P P P . P
# R . B Q K B N R
# r n b q k . n r
# p p p p p p b p
# . . . . . . p .
# . . . . . . . .
# . . N . . . . .
# . . . . . . P .
# P P P P P P . P
# R . B Q K B N R
# r n b q k . n r
# p p p p p p b .
# . . . . . . p p
# . . . . . . . .
# . . N . . . . .
# . . . . . . P .
# P P P P P P . P
# R . B Q K B N R
# r n b q k . n r
# p p p p p p b .
# . . . . . . p p
# . . . . . . . .
# . . N . . . . .
# . . . . . . P B
# P P P P P P . P
# R . B Q K . N R
# r n b q k . n r
# p p p p . p b .
# . . . . p . p p
# . . . . . . . .
# . . N . . . . .
# . . . . . . P B
# P P P P P P . P
# R . B Q K . N R
# r n b q k . n r
# p p p p . p b .
# . . . . p . p p
# . . . . . . . .
# . . N . . . . .
# . P . . . . P B
# P . P P P P . P
# R . B Q K . N R
# r n b q k . n r
# p p p p . p b .
# . . . . . . p p
# . . . . p . . .
# . . N . . . . .
# . P . . . . P B
# P . P P P P . P
# R . B Q K . N R
# r n b q k . n r
# p p p p . p b .
# . . . . . . p p
# . . . . p . . .
# P . N . . . . .
# . P . . . . P B
# . . P P P P . P
# R . B Q K . N R
# r n b q k . n r
# p p p p . . b .
# . . . . . p p p
# . . . . p . . .
# P . N . . . . .
# . P . . . . P B
# . . P P P P . P
# R . B Q K . N R
# r n b q k . n r
# p p p p . . b .
# . . . . . p p p
# . . . . p . . .
# P . . . . . . .
# . P . . . . P B
# . N P P P P . P
# R . B Q K . N R
# r n b q k . n r
# p . p p . . b .
# . . . . . p p p
# . p . . p . . .
# P . . . . . . .
# . P . . . . P B
# . N P P P P . P
# R . B Q K . N R
# r n b q k . n r
# p . p p . . b .
# . . . . . p p p
# . p . . p . . .
# P . P . . . . .
# . P . . . . P B
# . N . P P P . P
# R . B Q K . N R
# r n b q k . n r
# p . p p . . b .
# . . . . . p p p
# . . . . p . . .
# P . p . . . . .
# . P . . . . P B
# . N . P P P . P
# R . B Q K . N R
# r n b q k . n r
# p . p p . . b .
# . . . . . p p p
# . . . . p . . .
# P . p . . . . .
# . P . . . . P B
# . N . P P P . P
# R . B Q . K N R
# r n b q k . n r
# p . p p . . b .
# . . . . . p p p
# . . . . p . . .
# P . . . . . . .
# . P p . . . P B
# . N . P P P . P
# R . B Q . K N R
# r n b q k . n r
# p . p p . . b .
# . . . . . p p p
# . . . . p . . .
# P . . P . . . .
# . P p . . . P B
# . N . . P P . P
# R . B Q . K N R
# r n b q k b n r
# p . p p . . . .
# . . . . . p p p
# . . . . p . . .
# P . . P . . . .
# . P p . . . P B
# . N . . P P . P
# R . B Q . K N R
# r n b q k b n r
# p . p p . . . .
# . . . . . p p p
# . . . . p . . .
# P . . P . . . .
# . P p . . . P B
# . N . Q P P . P
# R . B . . K N R
# r n b q k . n r
# p . p p . . . .
# . . . . . p p p
# . . . . p . . .
# P b . P . . . .
# . P p . . . P B
# . N . Q P P . P
# R . B . . K N R
# r n b q k . n r
# p . p p . . . .
# . . . . . p p p
# . . . . p . . .
# P b . P . . . .
# . P p . . . P B
# . N . Q P P . P
# R . B . K . N R
# r n b q k . n r
# p . p p . . . .
# . . . . . p p p
# . . . . . . . .
# P b . p . . . .
# . P p . . . P B
# . N . Q P P . P
# R . B . K . N R
# r n b q k . n r
# p . p p . . . .
# . . . . . p p p
# . . . . . . . .
# P b . p . P . .
# . P p . . . P B
# . N . Q P . . P
# R . B . K . N R
# r . b q k . n r
# p . p p . . . .
# . . n . . p p p
# . . . . . . . .
# P b . p . P . .
# . P p . . . P B
# . N . Q P . . P
# R . B . K . N R
# r . b q k . n r
# p . p p . . . .
# . . n . . p p p
# . . . . . . . .
# P b . p . P . .
# . P p . . . P .
# . N . Q P . B P
# R . B . K . N R
# r . b q k b n r
# p . p p . . . .
# . . n . . p p p
# . . . . . . . .
# P . . p . P . .
# . P p . . . P .
# . N . Q P . B P
# R . B . K . N R
# r . b q k b n r
# p . p p . . . .
# . . n . . p p p
# . . . . . . . .
# P . . p . P . .
# . P p . . . P .
# . N . Q P . B P
# R . B K . . N R
# r . b q k b n r
# p . p p . . . .
# . . . . . p p p
# . . . . n . . .
# P . . p . P . .
# . P p . . . P .
# . N . Q P . B P
# R . B K . . N R
# r . b q k b n r
# p . p p . . . .
# . . . . . p p p
# . . . . n . . .
# P . . p . P . .
# . P p . . . P N
# . N . Q P . B P
# R . B K . . . R
# r . b q k b n r
# p . p . . . . .
# . . . . . p p p
# . . . p n . . .
# P . . p . P . .
# . P p . . . P N
# . N . Q P . B P
# R . B K . . . R
# r . b q k b n r
# p . p . . . . .
# . . . . . p p p
# . . . p n . . .
# P . . p . P . .
# . P p . . . P N
# . N . Q P . B P
# R . B K . R . .
# r . b q . b n r
# p . p . . k . .
# . . . . . p p p
# . . . p n . . .
# P . . p . P . .
# . P p . . . P N
# . N . Q P . B P
# R . B K . R . .
# r . b q . b n r
# p . p . . k . .
# . . . . . p p p
# . . . p n . . .
# P . . p . P . .
# . P p . . . P N
# . N Q . P . B P
# R . B K . R . .
# r . b q . b n r
# p . p . . k . .
# . . . . . p p p
# . . . p n . . .
# P . . p . P . .
# . P . . . . P N
# . p Q . P . B P
# R . B K . R . .
# r . b q . b n r
# p . p . . k . .
# . . . . . p p p
# . . . p P . . .
# P . . p . . . .
# . P . . . . P N
# . p Q . P . B P
# R . B K . R . .
# r . . q . b n r
# p . p . . k . .
# . . . . . p p p
# . . . p P . . .
# P . . p . . . .
# . P . . . . P b
# . p Q . P . B P
# R . B K . R . .
# r . . q . b n r
# p . p . . k . .
# . . . . . p p p
# . . . p P . . .
# P . . p . . . .
# . P . . . . P b
# . p Q . P . B P
# R . B K . . . R
# r . . q . b n r
# p . p . . k . .
# . . . . . p p p
# . . . p P . . .
# P . . p . . . .
# . P . . . . P b
# . . Q . P . B P
# b . B K . . . R
# r . . q . b n r
# p . p . . k . .
# . . . . . p p p
# . . . p P . . .
# P . . p B . . .
# . P . . . . P b
# . . Q . P . . P
# b . B K . . . R
# r . . q . b n .
# p . p . . k . r
# . . . . . p p p
# . . . p P . . .
# P . . p B . . .
# . P . . . . P b
# . . Q . P . . P
# b . B K . . . R
# r . . q . b n .
# p . p . . k . r
# . . . . . p p p
# . . . p P . . .
# P . . p B . . .
# . P . . . . P b
# . . Q . P . . P
# b . B K . . R .
# . . r q . b n .
# p . p . . k . r
# . . . . . p p p
# . . . p P . . .
# P . . p B . . .
# . P . . . . P b
# . . Q . P . . P
# b . B K . . R .
# . . r q . b n .
# p . Q . . k . r
# . . . . . p p p
# . . . p P . . .
# P . . p B . . .
# . P . . . . P b
# . . . . P . . P
# b . B K . . R .
# . . r . . b n .
# p . Q . q k . r
# . . . . . p p p
# . . . p P . . .
# P . . p B . . .
# . P . . . . P b
# . . . . P . . P
# b . B K . . R .
# . . r . . b n .
# p . Q . q k . r
# . . . . . p p p
# . . . p P . . .
# P . . p B . . .
# . P . . . . P b
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . Q . q k . r
# . . . . . p p p
# . . . p P . . .
# P . . p B . . .
# . P . . . . P b
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . . . q k . r
# . . Q . . p p p
# . . . p P . . .
# P . . p B . . .
# . P . . . . P b
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . . . q k . r
# . . Q . . p p p
# . . . p P b . .
# P . . p B . . .
# . P . . . . P .
# . B . . P . . P
# b . . K . . R .
# Q . . r . b n .
# p . . . q k . r
# . . . . . p p p
# . . . p P b . .
# P . . p B . . .
# . P . . . . P .
# . B . . P . . P
# b . . K . . R .
# Q . . r . b n .
# p . . . q k . r
# . . . . . p . p
# . . . p P b p .
# P . . p B . . .
# . P . . . . P .
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . . . q k . r
# . . Q . . p . p
# . . . p P b p .
# P . . p B . . .
# . P . . . . P .
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . . . q k . r
# . . Q . . p . p
# . . . p P . p .
# P . . p B . b .
# . P . . . . P .
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . . . q k . r
# . . . . . p . p
# . . . p P . p .
# P . Q p B . b .
# . P . . . . P .
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . . . . k . r
# . . . . q p . p
# . . . p P . p .
# P . Q p B . b .
# . P . . . . P .
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . . . . k . r
# . . . . q p . p
# . Q . p P . p .
# P . . p B . b .
# . P . . . . P .
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . . . . k . r
# . . . . q p . p
# . Q . p P . p .
# P . . p B . . .
# . P . . . b P .
# . B . . P . . P
# b . . K . . R .
# . . . r . b n .
# p . . . . k . r
# . . . . q p . p
# . Q . p P . p .
# P . . B B . . .
# . P . . . b P .
# . . . . P . . P
# b . . K . . R .
# . . . r . . n .
# p . . . . k . r
# . . . . q p . p
# . Q b p P . p .
# P . . B B . . .
# . P . . . b P .
# . . . . P . . P
# b . . K . . R .
# . . . r . . n .
# p . . . . k . r
# . . . . q p . p
# . Q b B P . p .
# P . . B . . . .
# . P . . . b P .
# . . . . P . . P
# b . . K . . R .
# . . . r . . n .
# p . . . . k . r
# . . . . q . . p
# . Q b B p . p .
# P . . B . . . .
# . P . . . b P .
# . . . . P . . P
# b . . K . . R .
# . . . r . . n .
# p . . . . k . r
# . . . . q . . p
# . Q b B p . p .
# P . . . . . . .
# . P . . B b P .
# . . . . P . . P
# b . . K . . R .
# . . . r . . n .
# p . . . . k . r
# . . . . q . . p
# . Q . B p . p .
# P . . . . . . .
# b P . . B b P .
# . . . . P . . P
# b . . K . . R .
# . . . r . . n .
# p . . . . k . r
# Q . . . q . . p
# . . . B p . p .
# P . . . . . . .
# b P . . B b P .
# . . . . P . . P
# b . . K . . R .
# . . . r . . n .
# p . . . . k . r
# Q . . . q . . p
# . . . B p . p .
# P . . . b . . .
# b P . . B . P .
# . . . . P . . P
# b . . K . . R .
# . . Q r . . n .
# p . . . . k . r
# . . . . q . . p
# . . . B p . p .
# P . . . b . . .
# b P . . B . P .
# . . . . P . . P
# b . . K . . R .
# . . Q r . . n .
# p . . . . k . r
# . . . . q . . p
# . . b B p . p .
# P . . . b . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . . R .
# . . . r . . n .
# p . . . . k . r
# . . Q . q . . p
# . . b B p . p .
# P . . . b . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . . R .
# . . . . . r n .
# p . . . . k . r
# . . Q . q . . p
# . . b B p . p .
# P . . . b . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . . R .
# . . . . . r n .
# p . . . . k . r
# . . Q . q . . p
# . . b B p . p .
# P . . . b . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . R . .
# . . . . . r n .
# p . . . . k . r
# . . Q . q . . p
# . . b B p b p .
# P . . . . . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . R . .
# . . . . . r n .
# p . . . . k . r
# . . . . Q . . p
# . . b B p b p .
# P . . . . . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . R . .
# . . . . . r n .
# p . . . . . k r
# . . . . Q . . p
# . . b B p b p .
# P . . . . . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . R . .
# . . . . . r n .
# p . . . . . k r
# . . . . . . . Q
# . . b B p b p .
# P . . . . . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . R . .
# . . . . . r n .
# p . . . . . k .
# . . . . . . . r
# . . b B p b p .
# P . . . . . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . R . .
# . . . . . r n .
# p . . . . . k .
# . . . . . . . r
# . . b . p b p .
# P . . . B . . .
# . P . . B . P .
# . . . . P . . P
# b . . K . R . .
# . . . . . r n .
# p . . . . . k .
# . . . . . . . .
# . . b . p b p .
# P . . . B . . r
# . P . . B . P .
# . . . . P . . P
# b . . K . R . .
# . . . . . r n .
# p . . . . . k .
# . . . . . . . .
# . . b . p b p .
# P . . . B . . r
# . P . . B . P .
# . . . K P . . P
# b . . . . R . .
# . . . . r . n .
# p . . . . . k .
# . . . . . . . .
# . . b . p b p .
# P . . . B . . r
# . P . . B . P .
# . . . K P . . P
# b . . . . R . .
# . . . . r . n .
# p . . . . . k .
# . . . . . . . .
# . . b . p B p .
# P . . . . . . r
# . P . . B . P .
# . . . K P . . P
# b . . . . R . .
# . . . . r . n .
# p . . . . . k .
# . . . . . . . .
# . . b . p B p r
# P . . . . . . .
# . P . . B . P .
# . . . K P . . P
# b . . . . R . .
# . . . . r . n .
# p . . . . . k .
# . . . . . . . .
# . . b . p B p r
# P . . . . . . .
# . P . . B . P .
# . . . K P . . P
# R . . . . . . .
# . . . . r . n .
# p . . . . . k .
# . . . . . . . .
# . . b . p B p .
# P . . . . . . r
# . P . . B . P .
# . . . K P . . P
# R . . . . . . .
# . . . . r . n .
# p . . . . . k .
# . . . . . . . .
# . . b . p B p .
# P . . . . . . r
# . P . . B . P .
# . . . K P . . P
# . . . R . . . .
# . . . . r . n .
# p . . . . . k .
# . . . . . . . .
# . . b . p B p .
# P . r . . . . .
# . P . . B . P .
# . . . K P . . P
# . . . R . . . .
# . . . . r . n .
# p . . . . . k .
# . . . . . . . .
# . . b . p B p .
# P . r . . . . .
# . P . . B . P .
# . . . K P . . P
# . . . . . . R .
# . . . . r . . .
# p . . . n . k .
# . . . . . . . .
# . . b . p B p .
# P . r . . . . .
# . P . . B . P .
# . . . K P . . P
# . . . . . . R .
# . . . . r . . .
# p . . . n . k .
# . . . . . . . .
# . . b . p B p .
# P . r . . . . .
# . P . . B . P .
# . . . K P . . P
# . . . . . R . .
# . . . . r . . .
# p . . . n . . .
# . . . . . . . k
# . . b . p B p .
# P . r . . . . .
# . P . . B . P .
# . . . K P . . P
# . . . . . R . .
# . . . . r . . .
# p . . . n . . B
# . . . . . . . k
# . . b . p . p .
# P . r . . . . .
# . P . . B . P .
# . . . K P . . P
# . . . . . R . .
# . . . . r . . .
# p . . . n . . B
# . . . . . . . k
# . . b . p . p .
# P . . . . r . .
# . P . . B . P .
# . . . K P . . P
# . . . . . R . .
# . . . . r . . .
# p . . . n . . B
# . . . . . . . k
# . . b . p . p .
# P . . B . r . .
# . P . . . . P .
# . . . K P . . P
# . . . . . R . .
# . . . . r . . .
# p . . . n . . B
# . . . . . . . k
# . . . . p . p .
# P b . B . r . .
# . P . . . . P .
# . . . K P . . P
# . . . . . R . .
# . . . . r . . .
# p . . . n . . B
# . . . . . . . k
# . . . . p . p .
# P b . B . r . .
# . P . . . . P .
# . . . . P . . P
# . . . K . R . .
# . . . . r . . .
# p . . . n . . B
# . . . . . . . k
# . . . . p . p .
# P b . B . . . .
# . P . . . . P .
# . . . . P r . P
# . . . K . R . .
# . . . . r . . .
# p . . . n . . B
# . . . . . . . k
# . . . . p . p .
# P b . B . . . .
# . P . . . . P .
# . . . . P R . P
# . . . K . . . .
# . . . . r . . .
# p . . . n . . B
# . . . . . . . k
# . . b . p . p .
# P . . B . . . .
# . P . . . . P .
# . . . . P R . P
# . . . K . . . .
# . . . . r . . .
# p . . . n . . .
# . . . . . . . k
# . . b . p . p .
# P . . B B . . .
# . P . . . . P .
# . . . . P R . P
# . . . K . . . .
# . r . . . . . .
# p . . . n . . .
# . . . . . . . k
# . . b . p . p .
# P . . B B . . .
# . P . . . . P .
# . . . . P R . P
# . . . K . . . .
# . r . . . . . .
# p . . . n . . .
# . . . . . . . k
# . . b . p . p .
# P . . . B . . .
# . P . . B . P .
# . . . . P R . P
# . . . K . . . .
# . . . r . . . .
# p . . . n . . .
# . . . . . . . k
# . . b . p . p .
# P . . . B . . .
# . P . . B . P .
# . . . . P R . P
# . . . K . . . .
# . . . r . . . .
# p . . . n . . .
# . . . . . . . k
# . . b . p . p .
# P . . . . . . .
# . P . B B . P .
# . . . . P R . P
# . . . K . . . .
# . . . r . . . .
# p . . . . . . .
# . . . . . . n k
# . . b . p . p .
# P . . . . . . .
# . P . B B . P .
# . . . . P R . P
# . . . K . . . .
# . . . r . . . .
# p . . . . . . .
# . . . . . . n k
# . . b . p . p .
# P P . . . . . .
# . . . B B . P .
# . . . . P R . P
# . . . K . . . .
# . . . r . . . .
# p . . . . . . .
# . b . . . . n k
# . . . . p . p .
# P P . . . . . .
# . . . B B . P .
# . . . . P R . P
# . . . K . . . .
# . . . r . R . .
# p . . . . . . .
# . b . . . . n k
# . . . . p . p .
# P P . . . . . .
# . . . B B . P .
# . . . . P . . P
# . . . K . . . .
# . . . r . R . .
# p . . . . . . .
# . . . . . . n k
# . . b . p . p .
# P P . . . . . .
# . . . B B . P .
# . . . . P . . P
# . . . K . . . .
# . . . r . R . .
# p . . . . . . .
# . . . . . . n k
# . . b . p . p .
# P P . . . . . .
# . . . B B . P .
# . . . . P . . P
# . . . . K . . .
# . . . r . R . .
# p . . . . . . .
# . . . b . . n k
# . . . . p . p .
# P P . . . . . .
# . . . B B . P .
# . . . . P . . P
# . . . . K . . .
# . . . r . R . .
# p . . . . . . .
# . . . b . . n k
# . . . . p . p .
# P P . . . . . .
# . . . B B . P .
# . . . K P . . P
# . . . . . . . .
# . . r . . R . .
# p . . . . . . .
# . . . b . . n k
# . . . . p . p .
# P P . . . . . .
# . . . B B . P .
# . . . K P . . P
# . . . . . . . .
# . . r . . R . .
# p . . . . . . .
# B . . b . . n k
# . . . . p . p .
# P P . . . . . .
# . . . . B . P .
# . . . K P . . P
# . . . . . . . .
# . . . . . R . .
# p . . . . . . .
# B . . b . . n k
# . . r . p . p .
# P P . . . . . .
# . . . . B . P .
# . . . K P . . P
# . . . . . . . .
# R . . . . . . .
# p . . . . . . .
# B . . b . . n k
# . . r . p . p .
# P P . . . . . .
# . . . . B . P .
# . . . K P . . P
# . . . . . . . .
# R . . . . n . .
# p . . . . . . .
# B . . b . . . k
# . . r . p . p .
# P P . . . . . .
# . . . . B . P .
# . . . K P . . P
# . . . . . . . .
# R . . . . n . .
# p . . . . . . .
# B . . b . . . k
# . . r . p . p .
# P P . . . . . .
# . . . . B . P .
# . . . . P . . P
# . . . . K . . .
# R . . . . . . .
# p . . . . . . .
# B . . b . . n k
# . . r . p . p .
# P P . . . . . .
# . . . . B . P .
# . . . . P . . P
# . . . . K . . .
# R . . . . . . .
# p . . . . . . .
# . . . b . . n k
# . . r . p . p .
# P P B . . . . .
# . . . . B . P .
# . . . . P . . P
# . . . . K . . .
# R . . . . . . .
# p . . . . . . .
# . . . b . . n k
# . r . . p . p .
# P P B . . . . .
# . . . . B . P .
# . . . . P . . P
# . . . . K . . .
# R . . . . . . .
# p . . . . . . .
# . . . b . . n k
# . r . . p . p .
# P P B . . . . .
# . . . . B . P .
# . . . . P . . P
# . . . K . . . .
# R . . . . . . .
# p . . . . . . .
# . . . b . . n k
# . . r . p . p .
# P P B . . . . .
# . . . . B . P .
# . . . . P . . P
# . . . K . . . .
# R . . . . . . .
# p . . . . . . .
# . . . b . . n k
# . B r . p . p .
# P P . . . . . .
# . . . . B . P .
# . . . . P . . P
# . . . K . . . .
# R . . . . n . .
# p . . . . . . .
# . . . b . . . k
# . B r . p . p .
# P P . . . . . .
# . . . . B . P .
# . . . . P . . P
# . . . K . . . .
# . . . R . n . .
# p . . . . . . .
# . . . b . . . k
# . B r . p . p .
# P P . . . . . .
# . . . . B . P .
# . . . . P . . P
# . . . K . . . .
# . . . R . n . .
# p . . . . . . .
# . . . b . . . k
# . B . . p . p .
# P P . . . . . .
# . . r . B . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . n . .
# p . . . . . . .
# . . . R . . . k
# . B . . p . p .
# P P . . . . . .
# . . r . B . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . n . .
# p . . . . . k .
# . . . R . . . .
# . B . . p . p .
# P P . . . . . .
# . . r . B . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . n . .
# p . . . . . k .
# R . . . . . . .
# . B . . p . p .
# P P . . . . . .
# . . r . B . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . . .
# p . . . . . k .
# R . . . n . . .
# . B . . p . p .
# P P . . . . . .
# . . r . B . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . . .
# p . . . . . k .
# R . . . n . . .
# . B . . p . p .
# P P . B . . . .
# . . r . . . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . k .
# p . . . . . . .
# R . . . n . . .
# . B . . p . p .
# P P . B . . . .
# . . r . . . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . k .
# p . . . . . . .
# . . R . n . . .
# . B . . p . p .
# P P . B . . . .
# . . r . . . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . k .
# p . . . . . . .
# . . R . n . . .
# . B . . p . p .
# P P . B . . . .
# . . . . r . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . B . . p . p .
# P P . B . . . .
# . . . . r . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . B . . p . p .
# P P . B . . . .
# r . . . . . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . B B . p . p .
# P P . . . . . .
# r . . . . . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . B B . p . p .
# P P . . . . . .
# . . . r . . P .
# . . . . P . . P
# . . . K . . . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . B B . p . p .
# P P . . . . . .
# . . . r . . P .
# . . . . P . . P
# . . . . K . . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . B B . p . p .
# P P . . . . . .
# r . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . B B . p . p .
# P P . . . . . .
# r . . . . . P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . B B . p . . .
# P P . . . . p .
# r . . . . . P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . . B . p . . .
# P P B . . . p .
# r . . . . . P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . k .
# p . . . . . . .
# . . . R n . . .
# . . B . p . . .
# P P B . . . p .
# . . . . r . P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . k .
# p . . . . . . .
# . . R . n . . .
# . . B . p . . .
# P P B . . . p .
# . . . . r . P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . . .
# p . . . . . . k
# . . R . n . . .
# . . B . p . . .
# P P B . . . p .
# . . . . r . P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . . .
# p . . . . . . k
# . . R B n . . .
# . . . . p . . .
# P P B . . . p .
# . . . . r . P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . . .
# p . n . . . . k
# . . R B . . . .
# . . . . p . . .
# P P B . . . p .
# . . . . r . P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . . .
# p . n . . . . k
# . . R . . . . .
# . . . . B . . .
# P P B . . . p .
# . . . . r . P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . . .
# p . n . . . . k
# . . R . . . . .
# . . . . B . . .
# P P B . . . p .
# . . . . . r P .
# . . . . P . . P
# . . . . . K . .
# . . . . . . . .
# p . n . . . . k
# . . R . . . . .
# . . . . B . . .
# P P B . . . p .
# . . . . . r P .
# . . . . P . . P
# . . . . K . . .
# . . . . . . . .
# p . n . . r . k
# . . R . . . . .
# . . . . B . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . . . . . . . B
# p . n . . r . k
# . . R . . . . .
# . . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . . . . . . . B
# . . n . . r . k
# . . R . . . . .
# p . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . . . . . . . B
# . . n . . r . k
# . . . R . . . .
# p . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . . . . . . . B
# . . . . . r . k
# n . . R . . . .
# p . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . . . . . . . B
# . . . . . r . k
# n . . . . . . .
# p . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . R K . . .
# . . . . . . k B
# . . . . . r . .
# n . . . . . . .
# p . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . R K . . .
# . . . . . . k .
# . . . . . r . .
# n . . . . . . .
# p . . . B . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . R K . . .
# . . . . . . k .
# . . n . . r . .
# . . . . . . . .
# p . . . B . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . R K . . .
# . . . . . . k B
# . . n . . r . .
# . . . . . . . .
# p . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . R K . . .
# . . . . n . k B
# . . . . . r . .
# . . . . . . . .
# p . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . R K . . .
# . . . R n . k B
# . . . . . r . .
# . . . . . . . .
# p . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . . . R n k . B
# . . . . . r . .
# . . . . . . . .
# p . . . . . . .
# P P B . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . . . R n k . B
# . . . . . r . .
# . . . . B . . .
# p . . . . . . .
# P P . . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . . . R n k . B
# . . . r . . . .
# . . . . B . . .
# p . . . . . . .
# P P . . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . R . . n k . B
# . . . r . . . .
# . . . . B . . .
# p . . . . . . .
# P P . . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . R . . n k . B
# . . . . . . . .
# . . . r B . . .
# p . . . . . . .
# P P . . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . R . . n k . B
# . . . . . . . .
# . . . r B . . .
# p P . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . . K . . .
# . R . . n k . B
# . . . . . . . .
# . . . . B . . .
# p P . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . . . P . . P
# . . . r K . . .
# . R . . n k . B
# . . . . . . . .
# . . . . B . . .
# p P . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . . . P K . P
# . . . r . . . .
# . R . . n k . B
# . . . . . . . .
# . . . . B . . .
# p P . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . . r P K . P
# . . . . . . . .
# . . . . R k . B
# . . . . . . . .
# . . . . B . . .
# p P . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . . r P K . P
# . . . . . . . .
# . . . . k . . B
# . . . . . . . .
# . . . . B . . .
# p P . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . . r P K . P
# . . . . . . . .
# . . . . k . . .
# . . . . . . B .
# . . . . B . . .
# p P . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . . r P K . P
# . . . . . . . .
# . . . . k . . .
# . . . . . . B .
# . . . . B . . .
# p P . r . . . .
# P . . . . . p .
# . . . . . . P .
# . . . . P K . P
# . . . . . . . .
# . . . . k . . .
# . . . . . . B .
# . P . . B . . .
# p . . r . . . .
# P . . . . . p .
# . . . . . . P .
# . . . . P K . P
# . . . . . . . .
# . . . . k . . .
# . . . . . . B .
# . P . . B . . .
# p . . . . r . .
# P . . . . . p .
# . . . . . . P .
# . . . . P K . P
# . . . . . . . .
# . . . . k . . .
# . . . . . . B .
# . P . . B . . .
# p . . . . r . .
# P . . . . . p .
# . . . . . . P .
# . . . . P . K P
# . . . . . . . .
# . . . k . . . .
# . . . . . . B .
# . P . . B . . .
# p . . . . r . .
# P . . . . . p .
# . . . . . . P .
# . . . . P . K P
# . . . . . . . .
# . . . k . . . .
# . . . . . . B .
# . P . . . . . .
# p . . B . r . .
# P . . . . . p .
# . . . . . . P .
# . . . . P . K P
# . . . . . . . .
# . . . k . . . .
# . . . . . . B .
# . P . . . . . .
# p . . B . . . .
# P . . . . . p .
# . . . . . . P .
# . . . . P . K P
# . . . . . r . .
# . . . k . . . .
# . . . . . . B .
# . P . . . . . .
# p . . B . . . .
# P . . . . . p .
# . . . . P . P .
# . . . . . . K P
# . . . . . r . .
# . . . k . . . .
# . . . . . . B .
# . P . . . . . .
# p . . B . . . .
# P . . . . . p .
# . . . . P . P .
# . . . . . . K P
# . r . . . . . .
# . . . k . . . .
# . . . . . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . B . p .
# . . . . P . P .
# . . . . . . K P
# . r . . . . . .
# . . . . . . . .
# . . . k . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . B . p .
# . . . . P . P .
# . . . . . . K P
# . r . . . . . .
# . . . . . . . .
# . . . k . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B P . P .
# . . . . . . K P
# . r . . . . . .
# . . . . . . . .
# . . . k . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B P . P .
# . . . . . . K P
# . . . . . . r .
# . . . . . . . .
# . . . k . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B P . P .
# . . . . . K . P
# . . . . . . r .
# . . . . . . . .
# . . . k . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B P . P .
# . . . . . K r P
# . . . . . . . .
# . . . . . . . .
# . . . k . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B P . P .
# . . . . . . r P
# . . . . K . . .
# . . . . . . . .
# . . . k . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B P . P .
# . . . . r . . P
# . . . . K . . .
# . . . . . . . .
# . . . k . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B P . P .
# . . . . r . . P
# . . . K . . . .
# . . . . . . . .
# . . . k . . B .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B P . P .
# . . . . . . . r
# . . . K . . . .
# . . . . . . . B
# . . . k . . . .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B P . P .
# . . . . . . . r
# . . . K . . . .
# . . . . . . . B
# . . . k . . . .
# . P . . . . . .
# p . . . . . . r
# P . . . . . p .
# . . . B P . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . k . . . .
# . P . . . . . .
# p . . . B . . r
# P . . . . . p .
# . . . B P . P .
# . . . . . . . .
# . . . K . . . .
# . . k . . . . .
# . . . . . . . .
# . P . . . . . .
# p . . . B . . r
# P . . . . . p .
# . . . B P . P .
# . . . . . . . .
# . . . K . . . .
# . . k . . . . .
# . . . . . . . .
# . P . . . . . .
# p . . . B . . r
# P . . . B . p .
# . . . . P . P .
# . . . . . . . .
# . . . K . . . .
# . . k . . . . .
# . . . . . . . .
# . P . . . . . .
# p . . . r . . .
# P . . . B . p .
# . . . . P . P .
# . . . . . . . .
# . . . K . . . .
# . . k . . . . .
# . . . . . . . .
# . P . . . . . .
# p . . . r . . .
# P . . . . . p .
# . . . B P . P .
# . . . . . . . .
# . . . K . . . .
# . . k . . . . .
# . . . . . . . .
# . P . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B r . P .
# . . . . . . . .
# . . . K . . . .
# . . k . . . . .
# . P . . . . . .
# . . . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B r . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . P . k . . . .
# . . . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . B r . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . P . k . . . .
# B . . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . . r . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . P . k . . . .
# B . . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K r . . .
# . . . . . . . .
# . P . k . . . .
# B . . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . K . . . . .
# . . . . r . . .
# . . . . . . . .
# . P . k . . . .
# B . . . . . . .
# p . . . . . . .
# P . . . . . p .
# . . . . . . P .
# . . K . . . . .
# . . . . . . . r
# . . . . . . . .
# . P . k . . . .
# . . . . . . . .
# p . . . . . . .
# P . B . . . p .
# . . . . . . P .
# . . K . . . . .
# . . . . . . . r
# . . . . . . . .
# . P . k . . . .
# . . . . . . . .
# p . . . . . . .
# P . B . . . p r
# . . . . . . P .
# . . K . . . . .
# . . . . . . . .
# . . . . . . . .
# . P . k . B . .
# . . . . . . . .
# p . . . . . . .
# P . . . . . p r
# . . . . . . P .
# . . K . . . . .
# . . . . . . . .
# . . . . . . . .
# . P . . . B . .
# . . k . . . . .
# p . . . . . . .
# P . . . . . p r
# . . . . . . P .
# . . K . . . . .
# . . . . . . . .
# . . . . . . . .
# . P . . . . . .
# . . k . . . . .
# p . . . . . . .
# P . . . . . p r
# . B . . . . P .
# . . K . . . . .
# . . . . . . . .
# . . . . . . . .
# . P . . . . . .
# . . . . . . . .
# p . k . . . . .
# P . . . . . p r
# . B . . . . P .
# . . K . . . . .
# . . . . . . . .
# . . . . . . . .
# . P . . . . . .
# . . . . . . . .
# p . k . . . . .
# P . . . . . p r
# . B . . . . P .
# . . . K . . . .
# . . . . . . . .
# . . . . . . . .
# . P . . . . . .
# . . . . . . . .
# p . . . . . . .
# P . . k . . p r
# . B . . . . P .
# . . . K . . . .
# . . . . . . . .
# . . . . . . B .
# . P . . . . . .
# . . . . . . . .
# p . . . . . . .
# P . . k . . p r
# . . . . . . P .
# . . . K . . . .
# . . . . . . . .
# . . . . . . B .
# . P . . . . . .
# . . . . . . . .
# p . . . . . . .
# P . . k . . p .
# . . . . . . P r
# . . . K . . . .
# . . . . . . . .
# . . . . . . B .
# . P . . . . . .
# . . . . . . . .
# p . . . . . . .
# P . . k . . p .
# . . . . . . P r
# . . . . . . . .
# . . . K . . . .
# . . . . . . B .
# . P . . . . . .
# . . . . . . . .
# p . . . . . . .
# P . . k . . p r
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . Q . . . . B .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# P . . k . . p r
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . Q . . . . B .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . r
# P . . k . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . B .
# . . Q . . . . .
# . . . . . . . .
# p . . . . . . r
# P . . k . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . B .
# . . Q . . . . .
# . . . . . . . r
# p . . . . . . .
# P . . k . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . B .
# . . . . . . . .
# . . . . . . . r
# Q . . . . . . .
# P . . k . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . B .
# . . . . . . . .
# . . . . . . . .
# Q . . . . . . r
# P . . k . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# Q . . . . . . r
# P . . k . . p .
# . . . . . . P .
# B . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# Q . . . . . r .
# P . . k . . p .
# . . . . . . P .
# B . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . Q r .
# P . . k . . p .
# . . . . . . P .
# B . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . r . .
# P . . k . . p .
# . . . . . . P .
# B . . . . . . .
# . . . K . . . .
# . . . . . . B .
# . . . . . . . .
# . . . . . . . .
# . . . . . r . .
# P . . k . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . B .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# P . . k . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# P . . k . . p .
# . B . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P r . k . . p .
# . B . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . . B . .
# . . . . . . . .
# . . . . . . . .
# P r . k . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . . B . .
# . . . . . . . .
# . . . . k . . .
# P r . . . . p .
# . . . . . . P .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . . B . .
# . . . . . . . .
# . . . . k . . .
# P r . . . . p .
# . . . . . . P .
# . . . . . . . .
# . . . . K . . .
# . . . . . . . .
# . . . . . B . .
# . . . . . . . .
# . . . . . . . .
# P r . . k . p .
# . . . . . . P .
# . . . . . . . .
# . . . . K . . .
# . . . . . . . .
# . . . . . B . .
# . . . . . . . .
# P . . . . . . .
# . r . . k . p .
# . . . . . . P .
# . . . . . . . .
# . . . . K . . .
# . . . . . . . .
# . . . . . B . .
# . . . . . . . .
# P . . . . . . .
# . r . . . . p .
# . . . . . k P .
# . . . . . . . .
# . . . . K . . .
# . . . . . . . .
# . . . . . . . .
# . . . . B . . .
# P . . . . . . .
# . r . . . . p .
# . . . . . k P .
# . . . . . . . .
# . . . . K . . .
# . . . . . . . .
# . . . . . . . .
# . . . . B . . .
# P . . . . . . .
# . . . . . . p .
# . . . . . k P .
# . r . . . . . .
# . . . . K . . .
# . . . . . . . .
# . . . B . . . .
# . . . . . . . .
# P . . . . . . .
# . . . . . . p .
# . . . . . k P .
# . r . . . . . .
# . . . . K . . .
# . . . . . . . .
# . . . B . . . .
# . . . . . . . .
# P . . . . . . .
# . . . . . . p .
# . . . . . k P .
# . . . . . . . r
# . . . . K . . .
# . . B . . . . .
# . . . . . . . .
# . . . . . . . .
# P . . . . . . .
# . . . . . . p .
# . . . . . k P .
# . . . . . . . r
# . . . . K . . .
# . . B . . . . .
# . . . . . . . .
# . . . . . . . .
# P . . . . . . .
# . . . . . . p .
# . . . . . k P .
# . . . . . . r .
# . . . . K . . .
# . . . . . . . .
# . B . . . . . .
# . . . . . . . .
# P . . . . . . .
# . . . . . . p .
# . . . . . k P .
# . . . . . . r .
# . . . . K . . .
# . . . . . . . .
# . B . . . . . .
# . . . . . . . .
# P . . . . . . .
# . . . . . . p .
# . . . . k . P .
# . . . . . . r .
# . . . . K . . .
# . . . . . . . .
# . . . . . . . .
# B . . . . . . .
# P . . . . . . .
# . . . . . . p .
# . . . . k . P .
# . . . . . . r .
# . . . . K . . .
# . . . . . . . .
# . . . . . . . .
# B . . . . . . .
# P . . . . . . .
# . . . . . . p .
# . . . . k . P .
# r . . . . . . .
# . . . . K . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P B . . . . . .
# . . . . . . p .
# . . . . k . P .
# r . . . . . . .
# . . . . K . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P B . . . . . .
# . . . . . . p .
# . . . . k . P .
# . . . . . . . .
# r . . . K . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P B . . . . . .
# . . . . . . p .
# . . . . k . P .
# . . . . . . . .
# r . . . K . . .
# Na3 g6 g3 Bg7 Nc4 h6 Bh3 e6 b3 e5 a4 f6 Nb2 b5 c4 bxc4 Kf1 c3 d4 Bf8 Qd2 Bb4 Ke1 exd4 f4 Nc6 Bg2 Bf8 Kd1 Ne5 Nh3 d5 Rf1 Kf7 Qc2 cxb2 fxe5 Bxh3 Rh1 bxa1=B Be4 Rh7 Rg1 Rc8 Qxc7+ Qe7 Bb2 Rd8 Qc6 Bf5 Qa8 g5 Qc6 Bg4 Qc4 Qe6 Qb5 Bf3 Bxd4 Bc5 Bxd5 fxe5 Be3 Ba3 Qa6 Be4 Qc8 Bc5 Qc6 Rf8 Rf1+ Bf5 Qxe6+ Kg7 Qxh6+ Rxh6 Be4 Rh4 Kd2 Re8 Bxf5 Rh5 Rxa1 Rh4 Rd1 Rc4 Rg1 Ne7 Rf1 Kh6 Bh7 Rf4 Bd4 Bb4+ Kd1 Rf2 Rxf2 Bc5 Be4 Rb8 Be3 Rd8+ Bd3 Ng6 b4 Bb6 Rf8 Bc5 Ke1 Bd6 Kd2 Rc8 Ba6 Rc5 Ra8 Nf8 Ke1 Ng6 Bc4 Rb5 Kd1 Rc5 Bb5 Nf8 Rd8 Rc3 Rxd6+ Kg7 Ra6 Ne6 Bd4 Kg8 Rc6 Re3 Rd6 Ra3 Bc5 Rd3+ Ke1 Ra3 Kf1 g4 Bc4 Re3 Rc6 Kh7 Bd6 Nc7 Bxe5 Rf3+ Ke1 Rf7 Bh8 a5 Rd6 Na6 Rd1 Kg8 Be5 Nc7 Bh8 Ne8 Rd8 Kf8 Be6 Rd7 Rb8 Rd6 b5 Rd1+ Kf2 Rd2 Rxe8+ Kxe8 Bg7 Rd5 b6 Rf5+ Kg2 Kd8 Bd5 Rf1 e3 Rb1 Be4 Kd7 Bd3 Rg1+ Kf2 Rg2+ Ke1 Re2+ Kd1 Rxh2 Bh8 Rh5 Be5 Kc8 Be4 Rxe5 Bd3 Rxe3 b7+ Kd7 Ba6 Re1+ Kc2 Rh1 Bc4 Rh4 Bf7 Kc6 Bb3 Kc5 Kd2 Kd4 Bg8 Rh3 Kd1 Rh4 b8=Q Rh5 Qc7 Rh6 Qxa5 Rh5 Ba2 Rg5 Qf5 Rxf5 Bg8 Rb5 Bb3 Rb4 Bf7 Ke5 Ke1 Ke4 a5 Kf3 Be6 Rb2 Bd7 Rh2 Bc8 Rg2 Bb7+ Ke3 Ba6 Ra2 Bb5 Ra1#
#
# 0-1
